# %% [markdown]
# <a href="https://colab.research.google.com/github/yashkaushik02/MLPractice/blob/main/Titanic.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **EDA using Univariate**
# Dataset: Titanic

# %%
import pandas as pd
import seaborn as sns

# %%
df = pd.read_csv('data_titanic.csv')

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# # **1. Categorical Data**
#
# ### a. countplot

# %%
print(df['Survived'].value_counts())
df['Survived'].value_counts().plot(kind='bar')
# sns.countplot(df['Survived'])
# Out:
# Survived
# 0    549
# 1    342
# Name: count, dtype: int64
# <Axes: xlabel='Survived'>

# %%
print(df['Pclass'].value_counts())
df['Pclass'].value_counts().plot(kind='bar')
# Out:
# Pclass
# 3    491
# 1    216
# 2    184
# Name: count, dtype: int64
# <Axes: xlabel='Pclass'>

# %%
print(df['Embarked'].value_counts())
df['Embarked'].value_counts().plot(kind='bar')
# Out:
# Embarked
# S    644
# C    168
# Q     77
# Name: count, dtype: int64
# <Axes: xlabel='Embarked'>

# %% [markdown]
# ### PieChart for getting values in percentage

# %%
from enum import auto
df['Survived'].value_counts().plot(kind='pie', autopct='%1.1f%%')
# Out:
# <Axes: ylabel='count'>

# %%
df['Pclass'].value_counts().plot(kind='pie', autopct='%1.1f%%')
# Out:
# <Axes: ylabel='count'>

# %%
df['Embarked'].value_counts().plot(kind='pie', autopct='%1.1f%%')
# Out:
# <Axes: ylabel='count'>

# %%
df['Sex'].value_counts().plot(kind='pie', autopct='%1.1f%%')
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# # **2. Numerical Data**
#
# ### a. Histogram

# %%
import matplotlib.pyplot as plt
plt.hist(df['Age'], bins=5)
# Out:
# (array([100., 346., 188.,  69.,  11.]),
#  array([ 0.42 , 16.336, 32.252, 48.168, 64.084, 80.   ]),
#  <BarContainer object of 5 artists>)

# %% [markdown]
# ### b. Distplot
# it also tells the skewness in the data

# %%
sns.displot(df['Age'])

# %% [markdown]
# ### C. BoxPlot

# %%
sns.boxplot(df['Age'])
# Out:
# <Axes: ylabel='Age'>

# %%
sns.boxplot(df['Fare'])
# Out:
# <Axes: ylabel='Fare'>
